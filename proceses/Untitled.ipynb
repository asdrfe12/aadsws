# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data-marketing.csv")
data.head(20)
# Out:
#     Month  Spend   Sales
# 0       1   1000    9914
# 1       2   4000   40487
# 2       3   5000   54324
# 3       4   4500   50044
# 4       5   3000   34719
# 5       6   4000   42551
# 6       7   9000   94871
# 7       8  11000  118914
# 8       9  15000  158484
# 9      10  12000  131348
# 10     11   7000   78504
# 11     12   3000   36284

# %%
df2 = pd.DataFrame({'Month': [6, 9,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 , 1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 ,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 ,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12],
                    'Sales': [9100, 150 ,7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 , 7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 , 7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 ,7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200],
    'Income': [500 , 500,1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500],
                    'Price': [100 , 100 ,100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250]})

# %%
df2 = pd.DataFrame({'Month': [6, 9,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 , 1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 ,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12 ,1,3,5,2,1,5,7,10,11,4,12,9,3,4,8,5,2,8,10,12],
                    'Sales': [9100, 150 ,7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 , 7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 , 7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200 ,7120,3144,2600,1290,600,500,1600,1200,1100,400,1200,900,300,400,800,500,200,800,1000,1200],
    'Income': [500 , 500,1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500 , 1000, 1100, 1200, 1200 , 1350 , 1500 , 1500 , 1500, 1600 , 1800 , 1900 , 2000 , 2100 , 2150 , 2300 , 2500 , 2500 , 2500 ,2500 ,2500],
                    'Price': [100 , 100 ,100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250 , 100, 112, 130, 140 , 200 , 210 , 250 , 290 , 222 , 250 , 240 , 221 , 225 , 210 , 230 , 240 , 250 , 250, 250, 250],
                   'Store Age': [7 , 10 , 13 , 15 , 10 , 3 , 1 , 2  , 14 , 8 , 14 , 3 , 2 , 6 , 2 , 5 , 8, 9 , 4 , 2,7 , 10 , 13 , 15 , 10 , 3 , 1 , 2  , 14 , 8 , 14 , 3 , 2 , 6 , 2 , 5 , 8, 9 , 4 , 2,7 , 10 , 13 , 15 , 10 , 3 , 1 , 2  , 14 , 8 , 14 , 3 , 2 , 6 , 2 , 5 , 8, 9 , 4 , 2,7 , 10 , 13 , 15 , 10 , 3 , 1 , 2  , 14 , 8 , 14 , 3 , 2 , 6 , 2 , 5 , 8, 9 , 4 , 2 , 4, 5],
                    'type': ['shoe store' , 'small market' , 'super market' , 'retailer' , 'cloth store' , 'food store' , 'vegetable store' , 'hat store' , 'piza store' , 'department store' , 'convenience store' , 'warehouse store' , 'bakery' , 'electronics store' , 'mobile store' , 'tv store' , 'cars store' , 'music' , 'plates store' , 'kitchen material','shoe store' , 'small market' , 'super market' , 'retailer' , 'cloth store' , 'food store' , 'vegetable store' , 'hat store' , 'piza store' , 'department store' , 'convenience store' , 'warehouse store' , 'bakery' , 'electronics store' , 'mobile store' , 'tv store' , 'cars store' , 'music' , 'plates store' , 'kitchen material','shoe store' , 'small market' , 'super market' , 'retailer' , 'cloth store' , 'food store' , 'vegetable store' , 'hat store' , 'piza store' , 'department store' , 'convenience store' , 'warehouse store' , 'bakery' , 'electronics store' , 'mobile store' , 'tv store' , 'cars store' , 'music' , 'plates store' , 'kitchen material','shoe store' , 'small market' , 'super market' , 'retailer' , 'cloth store' , 'food store' , 'vegetable store' , 'hat store' , 'piza store' , 'department store' , 'convenience store' , 'warehouse store' , 'bakery' , 'electronics store' , 'mobile store' , 'tv store' , 'cars store' , 'music' , 'plates store' , 'kitchen material','plates store' , 'kitchen material']})

# %%
frames = [df1, data]

# %%
df2.to_csv('marketing data.csv')

# %%
plt.plot(data['Month'], data['Sales'])
plt.title('Line Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.bar(data['Month'], data['Sales'])
plt.title('Bar Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.pie(data['Sales'], labels=data['Month'])
plt.title('Pie Chart')
plt.show()

# %%
# Create scatter plot
plt.scatter(data['Month'], data['Sales'])
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
